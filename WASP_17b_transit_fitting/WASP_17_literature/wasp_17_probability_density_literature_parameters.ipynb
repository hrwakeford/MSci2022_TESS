# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import scipy
import re
import scipy.stats as stats

import sys
sys.path.insert(0, r'/Users/Student/OneDrive/MSci project/MSci2022_TESS/packages')
from parameters_reading import read_df_params

# %%
#NASA Exoplanet Archieve of WASP-17b
# https://exoplanetarchive.ipac.caltech.edu/overview/WASP-17b

# %%
df = pd.read_csv("WASP_17_literature.csv")#, header=None)
df = df.set_index('Parameter')
df = df.drop(columns=df.columns[0])

# %%
df
# Out:
#                                                            Gaia DR2  \
# Parameter
# T_eff                                      6218.000+317.667-138.020
# systematic_radial_velocity  -47.977050594515134+/-1.270531493274848
# vsini                                                           ---
# stellar_mass                                                    ---
# stellar_radius                        1.6021124+0.0735638-0.1519570
# metallicity                                                     ---
# stellar_density                                                 ---
# log_g                                                           ---
# spectral_type                                                   ---
# stellar_luminosity                    0.5386836+0.0123959-0.0127602
# age                                                             ---
# colour                                                      #ff7f0e
#
#                            Bonomo et al. 2017 Stassun et al. 2017  \
# Parameter
# T_eff                               6650+/-80          6550+/-100
# systematic_radial_velocity                ---                 ---
# vsini                         10.05+0.88-0.79                 ---
# stellar_mass                    1.306+/-0.026         2.28+/-0.99
# stellar_radius                  1.572+/-0.056         1.49+/-0.19
# metallicity                   -0.190+/-0.090                -0.25
# stellar_density                           ---       0.980+/-0.200
# log_g                                     ---         4.20+/-0.20
# spectral_type                             ---                 ---
# stellar_luminosity                        ---                 ---
# age                               2.65+/-0.25                 ---
# colour                                #2ca02c             #d62728
#
#                            Sedaghati et al. 2016 Tsantaki et al. 2014  \
# Parameter
# T_eff                                        ---            6666+/-30
# systematic_radial_velocity                   ---                  ---
# vsini                                        ---                 9.93
# stellar_mass                       1.306+/-0.026                  ---
# stellar_radius                     1.572+/-0.056                  ---
# metallicity                                  ---        -0.04+/-0.03
# stellar_density                              ---                  ---
# log_g                                        ---          4.26+/-0.06
# spectral_type                                ---                  ---
# stellar_luminosity                           ---                  ---
# age                                          ---                  ---
# colour                                   #9467bd              #8c564b
#
#                            Knutson et al. 2014 Mortier et al. 2013  \
# Parameter
# T_eff                                      ---           6794+/-83
# systematic_radial_velocity                 ---                 ---
# vsini                                      ---                 ---
# stellar_mass                     1.286+/-0.079         1.20+/-0.08
# stellar_radius                             ---         0.73+/-0.08
# metallicity                    -0.020+/-0.090        -0.12+/-0.05
# stellar_density                            ---         0.32+/-0.01
# log_g                                      ---         4.83+/-0.09
# spectral_type                              ---                 ---
# stellar_luminosity                         ---                 ---
# age                                        ---                 ---
# colour                                 #e377c2             #7f7f7f
#
#                            Southworth et al. 2012 Anderson et al. 2011  \
# Parameter
# T_eff                                         ---            6650+/-80
# systematic_radial_velocity                    ---  -49.51367+/-0.00056
# vsini                                         ---      10.05+0.88-0.79
# stellar_mass                        1.286+/-0.079        1.306+/-0.026
# stellar_radius                      1.583+/-0.041        1.572+/-0.056
# metallicity                                   ---        -0.19+/-0.09
# stellar_density                     0.457+/-0.017        0.474+/-0.042
# log_g                               4.149+/-0.014        4.161+/-0.026
# spectral_type                                 ---                  ---
# stellar_luminosity                            ---                  ---
# age                                2.70+0.85-1.17                  ---
# colour                                    #bcbd22              #17becf
#
#                            Triaud et al. 2010 Anderson et al. 2010  \
# Parameter
# T_eff                               6650+/-80           6550+/-100
# systematic_radial_velocity                ---    -49.5128+/-0.0016
# vsini                       9.920+0.400-0.450            9.0+/-1.5
# stellar_mass                      1.20+/-0.12          1.20+/-0.12
# stellar_radius              1.579+0.067-0.060          1.38+/-0.20
# metallicity                     -0.19+/-0.09                   ---
# stellar_density             0.428+0.023-0.028                  ---
# log_g                             4.45+/-0.15                  ---
# spectral_type                              F4                  ---
# stellar_luminosity                        ---                  ---
# age                                       ---                  ---
# colour                                      b                    g
#
#                            ExoFOP-TESS TOI
# Parameter
# T_eff                                 6650
# systematic_radial_velocity             ---
# vsini                                  ---
# stellar_mass                           ---
# stellar_radius                 1.57+/-0.09
# metallicity                            ---
# stellar_density                        ---
# log_g                               4.1639
# spectral_type                          ---
# stellar_luminosity                     ---
# age                                    ---
# colour                                   r

# %%
df_ref_list = df.columns

df_T_eff_list = df.loc['T_eff'] #Stellar effective temperature (K)
df_metallicity_list = df.loc['metallicity'] #Metallicity ([Fe/H])
df_log_g_list = df.loc['log_g'] #Stellar surface gravity (log10(cm/s^2)

T_eff_list, T_eff_ref_list = read_df_params(df_T_eff_list, df_ref_list)
metallicity_list, metallicity_ref_list = read_df_params(df_metallicity_list, df_ref_list)
log_g_list, log_g_ref_list = read_df_params(df_log_g_list, df_ref_list)

# %%
fig, ax = plt.subplots(1, figsize=(8,6))

x = np.linspace(5000, 7300, 1000)
for obj, author in zip(T_eff_list, T_eff_ref_list):
    mu, upper, lower = obj
    sigma = max(abs(upper), abs(lower))
    if sigma > 0:
        colour = df[author]['colour']
        plt.plot(x, stats.norm.pdf(x, mu, sigma), label=author, color=colour)

plt.xlabel(r"Stellar Effective Temperature T$_{eff}$ (K)")
plt.ylabel("Probability Density")
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(8,6))

x = np.linspace(-0.6, 0.4, 1000)
for obj, author in zip(metallicity_list, metallicity_ref_list):
    mu, upper, lower = obj
    sigma = max(abs(upper), abs(lower))
    if sigma > 0:
        colour = df[author]['colour']
        plt.plot(x, stats.norm.pdf(x, mu, sigma), label=author, color=colour)

plt.xlabel(r"Stellar Metalicity ([Fe/H])")
plt.ylabel("Probability Density")
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(8,6))

x = np.linspace(3.5, 5.2, 1000)
for obj, author in zip(log_g_list, log_g_ref_list):
    mu, upper, lower = obj
    sigma = max(abs(upper), abs(lower))
    if sigma > 0:
        colour = df[author]['colour']
        plt.plot(x, stats.norm.pdf(x, mu, sigma), label=author, color=colour)

plt.xlabel(r"Stellar Surface Gravity log $g$ (log10(cm/s$^2$))")
plt.ylabel("Probability Density")
ax.legend()
plt.show()
