# %%
import os
import pickle
import lightkurve as lk
import astropy
from astropy.utils.masked import Masked

# %%
print("started")

# Config.
TIC = 'TIC 66818296' #WASP-17 / TIC 66818296
repo_path = r'C:\\Users\Student\\OneDrive\\MSci project\\MSci2022_TESS\\Lightkurve_code'
LOAD_FROM_CACHE = True


# Retrieve data.
cache_dir = os.path.join(repo_path, 'lc_cache', '{}.p'.format(TIC))
cache_pickle = os.path.join(cache_dir, '{}.p'.format(TIC))
if LOAD_FROM_CACHE and os.path.exists(cache_pickle):
    # From cache.
    with open(cache_pickle, 'rb') as f:
        lc_collection = pickle.load(f)
else:
    # From MAST data archive.
    print("Searching")
    search_result = lk.search_lightcurve(
        target=TIC,
        mission='TESS', author='SPOC')
    print("trying to download")
    lc_collection = search_result.download_all()
    print("Search done")
    print(lc_collection)
    # Save to cache.
    if not os.path.exists(cache_dir):
        os.mkdir(cache_dir)
    with open(cache_pickle, 'wb') as f:
        pickle.dump(lc_collection, f)

# Collate all sectors into one light curve.
lc = lc_collection.stitch(corrector_func=lambda x: x.
                          remove_nans().normalize(unit='unscaled'))

print("Done")
# Out:
# started
# Searching
# trying to download
# Search done
# LightCurveCollection of 2 objects:
#     0: <TessLightCurve LABEL="TIC 66818296" SECTOR=12 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 66818296" SECTOR=38 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# c:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Lightkurve_code\lightkurve_caching_script\cache_code.ipynb Cell 2 in <cell line: 12>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Lightkurve_code/lightkurve_caching_script/cache_code.ipynb#W1sZmlsZQ%3D%3D?line=27'>28</a>         os.mkdir(cache_dir)
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Lightkurve_code/lightkurve_caching_script/cache_code.ipynb#W1sZmlsZQ%3D%3D?line=28'>29</a>     with open(cache_pickle, 'wb') as f:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Lightkurve_code/lightkurve_caching_script/cache_code.ipynb#W1sZmlsZQ%3D%3D?line=29'>30</a>         pickle.dump(lc_collection, f)
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Lightkurve_code/lightkurve_caching_script/cache_code.ipynb#W1sZmlsZQ%3D%3D?line=31'>32</a> # Collate all sectors into one light curve.
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Lightkurve_code/lightkurve_caching_script/cache_code.ipynb#W1sZmlsZQ%3D%3D?line=32'>33</a> lc = lc_collection.stitch(corrector_func=lambda x: x.
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Lightkurve_code/lightkurve_caching_script/cache_code.ipynb#W1sZmlsZQ%3D%3D?line=33'>34</a>                           remove_nans().normalize(unit='unscaled'))
#
# PicklingError: Can't pickle <class 'astropy.utils.masked.core.MaskedQuantity'>: attribute lookup MaskedQuantity on astropy.utils.masked.core failed
