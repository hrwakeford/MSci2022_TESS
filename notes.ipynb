# %% [markdown]
# # Notebook

# %% [markdown]
# Some useful links
#
# https://ingeh.medium.com/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
#
# https://ingeh.medium.com/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed

# %% [markdown]
# ## 1. MCMC simulations with emcee
#
# https://emcee.readthedocs.io/en/stable/tutorials/line/

# %% [markdown]
# The following simulations of 1.x are a part of sector 12 (3 transit events) of WASP 17b

# %% [markdown]
# ## 1.1 WASP 17b sector 12 (first half, 3 transits)

# %% [markdown]
# ### 1.1.1 Simulation 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $T_{0}$ and $R_{p}/R_{*}$ converges value, however orbital period doesn't converges. Orbital inclination seems to diverage. Semi-major axis doesn't seem to converge well.
#
# Note: Scattering of walkers matter, and spread needs to be meaningful

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.1.2 Simulation 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $R_{p}/R_{*}$ has two branches

# %% [markdown]
# ### 1.1.3 Simulation 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Orbital period doesn't show a full normal distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Seems to show a good fit, however the transit depth is varying which leads to some sharp spikes in residuals on the transit events.
