# %%
#Uses exoplanet.org however this has not been updated since June 2018, to date, there is about ~5000 discovered exoplanets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
df = pd.read_csv('exoplanets.csv')

period = df["PER"]
radius = df["R"]

xlog = np.log(period)
ylog = np.log(radius)
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_13220\2489787140.py:1: DtypeWarning: Columns (4,5,10,11,17,18,23,24,26,27,30,33,38,39,44,45,50,51,56,57,62,63,70,71,73,74,79,80,81,82,88,89,95,96,105,106,109,110,115,116,117,124,125,130,131,137,143,144,149,150,159,160,161,162,172,173,174,179,180,182,188,189,195,196,201,202,205,206,211,212,217,218,223,224,229,230,235,236,241,242,247,248,253,254,259,260,265,266,268,269,270,271,273,278,279,284,285,290,291,294,295,301,302,304,305,310,311) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('exoplanets.csv')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_xscale('log', base=10) 
ax.set_yscale('log', base=10) 

ax1 = ax.twinx()
ax3 = ax.twiny()


ax3.set_xscale('log', base=10) 
ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax.scatter(df["PER"], df["R"], s=5, color="black")
ax.scatter(df.loc[df["EANAME"]=="WASP-17 b"]["PER"], df.loc[df["EANAME"]=="WASP-17 b"]["R"], s=100, label="WASP-17b") 
ax.scatter(df.loc[df["EANAME"]=="WASP-39 b"]["PER"], df.loc[df["EANAME"]=="WASP-39 b"]["R"], s=100, label="WASP-39b", marker="s") 
ax.scatter(df.loc[df["EANAME"]=="HAT-P-26 b"]["PER"], df.loc[df["EANAME"]=="HAT-P-26 b"]["R"], s=100, label="HAT-P-26b", marker="^")
ax.scatter(df.loc[df["EANAME"]=="HAT-P-32 b"]["PER"], df.loc[df["EANAME"]=="HAT-P-32 b"]["R"], s=100, label="HAT-P-32b", marker="D")




ax.axhline(1, linestyle='--', color="gray") #Jupiter radius
ax.axhline(0.267644, linestyle='--', color="gray") #Sub-neptune
ax.axhline(0.0892147, linestyle='--', color="gray") #Earth-sized
ax.annotate("Jupiter-sized", xy=(0.07, 0.76), color="gray", weight="semibold", size=17)
ax.annotate("Sub-neptune", xy=(0.07, 0.205), color="gray", weight="semibold", size=17)
ax.annotate("Earth-sized", xy=(0.07, 0.066), color="gray", weight="semibold", size=17)


ax.set_xlabel("Orbital period (days)", size=17)
ax.set_ylabel("Planet radius (Jupiter radii)", size=17)
 
ax1.set_xscale('log',base=10) 
ax1.set_yscale('log',base=10) 

ax.set_xlim(0.065, 1000)
ax.set_ylim(0.012, 10)


ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax1.set_yticklabels([])
ax3.set_xticklabels([])

ax.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax1.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax3.tick_params(which='both', direction = 'in', width=1.3, length=7)

ax.tick_params(which='minor', length=2.8)
ax1.tick_params(which='minor', length=2.8)
ax3.tick_params(which='minor', length=2.8)

ax.xaxis.set_tick_params(labelsize=17)
ax.yaxis.set_tick_params(labelsize=17)

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))

ax.legend(loc='lower right', prop={'size': 17})

plt.show()

# %%
fig, ax = plt.subplots()
ax.set_xscale('log', base=10) 
ax.set_yscale('log', base=10) 

ax1 = ax.twinx()
ax3 = ax.twiny()


ax3.set_xscale('log', base=10) 
ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax.scatter(df["PER"], df["MASS"], s=3, color="black")
ax.scatter(df.loc[df["EANAME"]=="WASP-17 b"]["PER"], df.loc[df["EANAME"]=="WASP-17 b"]["MASS"], s=15, label="WASP-17b") 
ax.scatter(df.loc[df["EANAME"]=="WASP-39 b"]["PER"], df.loc[df["EANAME"]=="WASP-39 b"]["MASS"], s=15, label="WASP-39b", marker="s") 
ax.scatter(df.loc[df["EANAME"]=="HAT-P-26 b"]["PER"], df.loc[df["EANAME"]=="HAT-P-26 b"]["MASS"], s=15, label="HAT-P-26b", marker="^")
ax.scatter(df.loc[df["EANAME"]=="HAT-P-32 b"]["PER"], df.loc[df["EANAME"]=="HAT-P-32 b"]["MASS"], s=15, label="HAT-P-32b", marker="D")



ax.axhline(1, linestyle='--', color="gray") #Jupiter radius
ax.axhline(0.267644, linestyle='--', color="gray") #Sub-neptune
ax.axhline(0.0892147, linestyle='--', color="gray") #Earth-sized
ax.annotate("Jupiter-sized", xy=(0.14, 0.65), color="gray", weight="semibold")
ax.annotate("Sub-neptune", xy=(0.14, 0.17), color="gray", weight="semibold")
ax.annotate("Earth-sized", xy=(0.14, 0.057), color="gray", weight="semibold")


ax.set_xlabel("Orbital period (days)")
ax.set_ylabel("Planet mass (Jupiter mass)")
 
ax1.set_xscale('log',base=10) 
ax1.set_yscale('log',base=10) 

ax.set_xlim(0.12, 1200)
ax.set_ylim(0.00009, 12)


ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax1.set_yticklabels([])
ax3.set_xticklabels([])

ax.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax1.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax3.tick_params(which='both', direction = 'in', width=1.3, length=7)

ax.tick_params(which='minor', length=2.8)
ax1.tick_params(which='minor', length=2.8)
ax3.tick_params(which='minor', length=2.8)

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))

ax.legend()

plt.show()

# %%
mass = df["MASS"]
radius = df["R"]

xlog = np.log(mass)
ylog = np.log(radius)
# Out:
# c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig, ax = plt.subplots()
ax.set_xscale('log', base=10) 
ax.set_yscale('log', base=10) 

ax1 = ax.twinx()
ax3 = ax.twiny()


ax3.set_xscale('log', base=10) 
ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax.scatter(df["MASS"], df["R"], s=5, color="black")
ax.scatter(df.loc[df["EANAME"]=="WASP-17 b"]["MASS"], df.loc[df["EANAME"]=="WASP-17 b"]["R"], label="WASP-17b") 
ax.scatter(df.loc[df["EANAME"]=="WASP-39 b"]["MASS"], df.loc[df["EANAME"]=="WASP-39 b"]["R"], label="WASP-39b", marker="s") 
ax.scatter(df.loc[df["EANAME"]=="HAT-P-26 b"]["MASS"], df.loc[df["EANAME"]=="HAT-P-26 b"]["R"], label="HAT-P-26b", marker="^")
ax.scatter(df.loc[df["EANAME"]=="HAT-P-32 b"]["MASS"], df.loc[df["EANAME"]=="HAT-P-32 b"]["R"], label="HAT-P-32b", marker="D")


ax.axhline(1, linestyle='--', color="gray") #Jupiter radius
ax.axhline(0.267644, linestyle='--', color="gray") #Sub-neptune
ax.axhline(0.0892147, linestyle='--', color="gray") #Earth-sized
ax.annotate("Jupiter-sized", xy=(0.00225, 0.76), color="gray", weight="semibold")
ax.annotate("Sub-neptune", xy=(0.00225, 0.205), color="gray", weight="semibold")
ax.annotate("Earth-sized", xy=(0.00225, 0.066), color="gray", weight="semibold")


ax.set_xlabel("Planet mass (Jupter mass)")
ax.set_ylabel("Planet radius (Jupiter radii)")
 
ax1.set_xscale('log',base=10) 
ax1.set_yscale('log',base=10) 

# ax.set_xlim(0.002, 10)
# ax.set_ylim(0.012, 12)


ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax1.set_yticklabels([])
ax3.set_xticklabels([])

ax.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax1.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax3.tick_params(which='both', direction = 'in', width=1.3, length=7)

ax.tick_params(which='minor', length=2.8)
ax1.tick_params(which='minor', length=2.8)
ax3.tick_params(which='minor', length=2.8)

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))

ax.legend()

plt.show()

# %%
mass = df["MASS"]
semimajor = df["A"]

xlog = np.log(semimajor)
ylog = np.log(mass)

# %%
fig, ax = plt.subplots()
ax.set_xscale('log', base=10) 
ax.set_yscale('log', base=10) 

ax1 = ax.twinx()
ax3 = ax.twiny()


ax3.set_xscale('log', base=10) 
ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax.scatter(df["A"], df["MASS"], s=5, color="black")
ax.scatter(df.loc[df["EANAME"]=="WASP-17 b"]["A"], df.loc[df["EANAME"]=="WASP-17 b"]["MASS"], label="WASP-17b") 
ax.scatter(df.loc[df["EANAME"]=="WASP-39 b"]["A"], df.loc[df["EANAME"]=="WASP-39 b"]["MASS"], label="WASP-39b", marker="s") 
ax.scatter(df.loc[df["EANAME"]=="HAT-P-26 b"]["A"], df.loc[df["EANAME"]=="HAT-P-26 b"]["MASS"], label="HAT-P-26b", marker="^")
ax.scatter(df.loc[df["EANAME"]=="HAT-P-32 b"]["A"], df.loc[df["EANAME"]=="HAT-P-32 b"]["MASS"], label="HAT-P-32b", marker="D")


ax.axhline(1, linestyle='--', color="gray") #Jupiter radius
ax.axhline(0.267644, linestyle='--', color="gray") #Sub-neptune
ax.axhline(0.0892147, linestyle='--', color="gray") #Earth-sized
ax.annotate("Jupiter-sized", xy=(0.00225, 0.76), color="gray", weight="semibold")
ax.annotate("Sub-neptune", xy=(0.00225, 0.205), color="gray", weight="semibold")
ax.annotate("Earth-sized", xy=(0.00225, 0.066), color="gray", weight="semibold")


ax.set_ylabel("Planet mass (Jupter mass)")
ax.set_xlabel("Semi-major axis (AU)")
 
ax1.set_xscale('log',base=10) 
ax1.set_yscale('log',base=10) 

# ax.set_xlim(0.002, 10)
# ax.set_ylim(0.012, 12)


ax1.set_ylim(ax.get_ylim())
ax3.set_xlim(ax.get_xlim())


ax1.set_yticklabels([])
ax3.set_xticklabels([])

ax.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax1.tick_params(which='both', direction = 'in', width=1.3, length=7)
ax3.tick_params(which='both', direction = 'in', width=1.3, length=7)

ax.tick_params(which='minor', length=2.8)
ax1.tick_params(which='minor', length=2.8)
ax3.tick_params(which='minor', length=2.8)

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))

ax.legend()

plt.show()
