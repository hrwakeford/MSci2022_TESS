# %%
import os
os.environ["OMP_NUM_THREADS"] = "4"

import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import corner
import batman
import emcee
import time
from multiprocessing import Pool
from IPython.display import display, Math
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as tck

from exotic_ld import StellarLimbDarkening

import pandas as pd
import pickle

# %%
def semi_major_axis_in_stellar_radii(semi_major_axis, R_star):
    """
    Converting the semi-major axis (AU) to (Stellar radii)

    Parameters
    ----------
    semi_major_axis : float
        Semi-major axis of the planet in AU.

    R_star : float
        Stellar radius in R_sun.

    Returns
    -------
    a_stellar_radii : float
        Semi-major axis of the planet in stellar radii.
    """
    #1 AU = 215.032 R_Sun

    a_stellar_radii = semi_major_axis * 215.032 / R_star

    return a_stellar_radii

# %%
TIC = 'TIC 420779000' #HAT-P-26b / TIC 420779000

search_result = lk.search_lightcurve(
    target=TIC,
    mission='TESS', author='SPOC')
print("trying to download")
lc_collection = search_result.download_all()
print("Search done")
print(lc_collection)
lc = lc_collection.stitch(corrector_func=lambda x: x.
                          remove_nans().normalize(unit='unscaled'))

lc = lc.remove_nans()
# Out:
# trying to download
# Search done
# LightCurveCollection of 1 objects:
#     0: <TessLightCurve LABEL="TIC 420779000" SECTOR=50 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lc
# Out:
# <TessLightCurve length=10871 LABEL="TIC 420779000" SECTOR=50 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                                   ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
#  2665.276621666103  1.0008752e+00 ... -3.7879929e-02  1.0244901e-01
# 2665.2780106009227  9.9939626e-01 ... -3.2004643e-02  1.0131135e-01
# 2665.2793995357433  9.9927253e-01 ... -3.7128687e-02  9.5918149e-02
# 2665.2807884705635  1.0043720e+00 ... -3.4576565e-02  1.0225669e-01
# 2665.2821774058493  1.0007608e+00 ... -3.8559388e-02  1.0009597e-01
# 2665.2835663406704  9.9956930e-01 ... -3.4752984e-02  1.0057126e-01
# 2665.2849552754915  9.9820203e-01 ... -3.9159257e-02  1.0016379e-01
# 2665.2863442103117  9.9677658e-01 ... -3.5147920e-02  1.0174066e-01
# 2665.2877331451323  9.9803406e-01 ... -3.7530947e-02  9.6270330e-02
#                ...            ... ...            ...            ...
#  2691.502118006213  9.9994731e-01 ...  7.5548537e-02 -7.9586990e-02
#  2691.503506892139  1.0003368e+00 ...  7.4154764e-02 -7.9884268e-02
# 2691.5048957780646  1.0007348e+00 ...  6.9023050e-02 -7.6593280e-02
# 2691.5062846639908  1.0033987e+00 ...  7.6111481e-02 -7.6250546e-02
# 2691.5076735499165  9.9537325e-01 ...  7.2018519e-02 -7.8273296e-02
#  2691.509062435376  1.0012926e+00 ...  7.2972029e-02 -7.7334732e-02
# 2691.5104513213014  9.9885923e-01 ...  1.0136519e-01 -8.1381574e-02
#  2691.511840207227  1.0029957e+00 ...  6.9132052e-02 -8.1135832e-02
# 2691.5132290931533  1.0012279e+00 ...  7.4461117e-02 -7.5107127e-02
#  2691.514617979079  9.9943751e-01 ...  7.2087333e-02 -8.0982015e-02

# %%
t = np.array(lc.time.btjd)
flux_data = np.array(lc.flux)
yerrs = np.array(lc.flux_err)

# %%
fig, ax = plt.subplots(1, figsize=(14,6))
plt.errorbar(t, flux_data, yerrs, fmt='.', color='Black', ecolor='LightGrey')


plt.ylabel("Normalised flux", size=17)
plt.xlabel("Time - 2457000 (BTJD days)", size=17)

ax.xaxis.set_tick_params(labelsize=17)
ax.yaxis.set_tick_params(labelsize=17)

ax.xaxis.set_minor_locator(tck.AutoMinorLocator())
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())

plt.show()

# %%
prior_Rs = 0.8564404 #R_sun, Gaia DR2

guess_params = batman.TransitParams()
guess_params.w = 46.0                                          #Knutson et al. 2014 - longitude of periastron (in degrees)
guess_params.ecc = 0.12 #Stassun et al. 2017
guess_params.limb_dark = "quadratic"                          #limb darkening model
guess_params.u = [0.43885935628841155, 0.17612013577695576]                            #limb darkening coefficients

# %%
def log_likelihood(prior_params, true_flux, yerrs):
    """
    
    Parameters
    ----------


    Returns
    -------
    
    """
    t_0, R_planet_stellar, orbital_period, orbital_inclination, semi_major_axis, eccentricity = prior_params

    guess_params.t0 = t_0
    guess_params.rp = R_planet_stellar
    guess_params.per = orbital_period
    guess_params.inc = orbital_inclination
    guess_params.a = semi_major_axis
    guess_params.ecc = eccentricity
    
    guess_m = batman.TransitModel(guess_params, t)
    guess_flux = guess_m.light_curve(guess_params)

    L1 = -0.5 * np.power((true_flux - guess_flux), 2) / np.power(yerrs, 2) #Sigma
    L2 = -0.5 * np.log(2 * np.pi * yerrs**2) #Sigma
    L3 = np.sum(L1) + np.sum(L2)
    return L3


def log_prior(prior_params):
    """
    
    Parameters
    ----------


    Returns
    -------
    
    """
    t_0, R_planet_stellar, orbital_period, orbital_inclination, semi_major_axis, eccentricity = prior_params

    P = 0.0
    if (t_0 < 2670.0) or (t_0 > 2671.0): #Days
        return -np.inf

    if (R_planet_stellar < 0.05) or (R_planet_stellar > 0.1):
        return -np.inf

    if (orbital_period < 4.1) or (orbital_period > 4.3): #Days
        return -np.inf

    if (orbital_inclination < 80) or (orbital_inclination > 90): #Degrees
        return -np.inf
    
    if (semi_major_axis < 5) or (semi_major_axis > 22): #AU
        return -np.inf

    if (eccentricity < 0.0) or (eccentricity > 0.5): #Eccentricity
        return -np.inf
    

    #Stassun et al. 2017
    # e = 0.12+/-0.06
    mu = 0.12
    sigma = 0.06
    P += -np.exp(-((np.log(eccentricity) - mu)**2)/2*(sigma**2)) / (sigma * eccentricity * np.sqrt(2*np.pi))

    return P

def log_prob(prior_params, true_flux, yerrs):
    lp = log_prior(prior_params)
    if (np.isinf(lp) == True):
        return -np.inf

    return log_likelihood(prior_params, true_flux, yerrs) + lp

# %%
prior_t0 = 2670.4 #(Days) Myself
prior_rprs = 0.0737 #Hartman et al. 2010
prior_per =  4.2345002 #(Days) Kokori et al. 2022
prior_inc =  88.6 #(Deg) Hartman et al. 2010
prior_a = semi_major_axis_in_stellar_radii(0.0479, prior_Rs) #(AU) Hartman et al. 2010
prior_eccen = 0.12 #Stassun et al. 2017

guess = [prior_t0, prior_rprs, prior_per, prior_inc, prior_a, prior_eccen]

# %%
scatter = 1E-8 #Walker scattering of the parameters

pos = guess + scatter * np.random.randn(20, len(guess))

nwalkers, ndim = pos.shape

filename = "HAT_P_26b.h5"
backend = emcee.backends.HDFBackend(filename)
backend.reset(nwalkers, ndim)

with Pool() as pool:
    start_time = time.time()
    print("Start:       {}".format(time.ctime(int(start_time))))
    
    sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob, args=(flux_data, yerrs), a=2)
    sampler.run_mcmc(pos, 50000, progress=True)
    
    end_time = time.time()
    execution_time = (end_time - start_time)
    print("End:         {}".format(time.ctime(int(end_time))))
    print("Time taken:  {:.2f} s".format(execution_time))
# Out:
# Start:       Sun Feb 12 20:53:58 2023
# 100%|██████████| 50000/50000 [1:33:32<00:00,  8.91it/s]
# End:         Sun Feb 12 22:27:31 2023
# Time taken:  5612.83 s

# %%
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# [148.56109806 246.8183503  115.51156624 292.47087076 258.71841434
#  227.76792721]

# %%
burnin = int(5 * np.max(tau))
thin = int(0.5 * np.min(tau))
flat_samples = sampler.get_chain(discard=burnin, thin=thin, flat=True)
print(flat_samples.shape)
# Out:
# (17020, 6)

# %%
filename = "HAT_P_26b_flat_samples.p"
file = open(filename, "wb")
pickle.dump(flat_samples, file)
file.close()

# %%
fig, axes = plt.subplots(len(guess), figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["$T_{0}$ (Days)", "$R_{p}/R_{*}$", "$P$ (Days)", "$i$ (Deg)", "$a/R_{*}$", "$e$"]

for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.axvline(x=burnin, color='red', ls="--",alpha=0.7)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])

axes[-1].set_xlabel("Step number")
plt.show()

# %%
labels = ["$T_{0}$ (Days)", "$R_{p}/R_{*}$", "Orbital Period (Days)", "Orbital Inclination (Deg)", "Semi-major axis ($a/R_{*}$)", "Eccentricity ($e$)"]
fig = corner.corner(
    flat_samples, labels=labels)

# %%
transit_params = []
for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.8f}_{{-{1:.10f}}}^{{{2:.10f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])

    val = "{}+{}-{}".format(mcmc[1], q[0], q[1])
    entry = [labels[i], val]
    transit_params.append(entry)

    display(Math(txt))

df = pd.DataFrame(data=transit_params)

df.to_csv("HAT_P_26b_params.csv",header=False, index=False)
# Out:
# $\displaystyle \mathrm{$T_{0}$ (Days)} = 2670.42455566_{-0.0010174591}^{0.0011167005}$
# $\displaystyle \mathrm{$R_{p}/R_{*}$} = 0.07203268_{-0.0016426431}^{0.0023328247}$
# $\displaystyle \mathrm{Orbital Period (Days)} = 4.23440104_{-0.0003399733}^{0.0003453000}$
# $\displaystyle \mathrm{Orbital Inclination (Deg)} = 85.11235036_{-3.1574842291}^{3.2926075818}$
# $\displaystyle \mathrm{Semi-major axis ($a/R_{*}$)} = 8.67694313_{-1.0737247956}^{0.7756359703}$
# $\displaystyle \mathrm{Eccentricity ($e$)} = 0.47795107_{-0.0318782524}^{0.0161858066}$
