# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import scipy
import re
import scipy.stats as stats

from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as tck


import sys
sys.path.insert(0, r'/Users/Student/OneDrive/MSci project/MSci2022_TESS/packages')
from parameters_reading import read_df_params

# %%
#NASA Exoplanet Archieve of WASP-17b
# https://exoplanetarchive.ipac.caltech.edu/overview/WASP-17b

# %%
df = pd.read_csv("WASP_17b_literature.csv")
df = df.set_index('Parameter')
df = df.drop(columns=df.columns[0])

# %%
df
# Out:
#                           Patel & Espinoza 2022      Ivshina & Winn 2022  \
# Parameter
# e                                           ---                      ---
# i                                           ---                      ---
# P                 3.7354300+0.0000071-0.0000074    3.7354826+/-0.0000015
# R                                           ---                      ---
# a                                           ---                      ---
# T_c                     2458638.33209+/-0.00026  2457192.70049+/-0.00089
# b                             0.180+0.130-0.100                      ---
# RpRs                       0.1218+0.0016-0.0014                      ---
# delta                                       ---                      ---
# transit_duration                            ---                      ---
# w                                           ---                      ---
# a/R*                             7.32+0.11-0.18                      ---
# colour                                  #ff7f0e                  #2ca02c
#
#                        Bonomo et al. 2017    Sedaghati et al. 2016  \
# Parameter
# e                                   0.020                        0
# i                         86.83+0.68-0.53          87.06+0.61-0.63
# P                   3.7354845+/-0.0000019                 3.735438
# R                           1.991+/-0.081            1.747+/-0.078
# a                       0.05151+/-0.00035          0.0513+/-0.0029
# T_c               2454592.80154+/-0.00005  2457192.69798+/-0.00028
# b                                     ---            0.361+/-0.069
# RpRs                                  ---        0.12345+/-0.00109
# delta                                 ---                      ---
# transit_duration                      ---                      ---
# w                                     ---                       90
# a/R*                                  ---            7.025+/-0.146
# colour                            #d62728                  #8c564b
#
#                    Southworth et al. 2012     Anderson et al. 2011  \
# Parameter
# e                                       0        0.028+0.015-0.018
# i                            86.71+/-0.30          86.83+0.68-0.56
# P                   3.7354845+/-0.0000019    3.7354380+/-0.0000068
# R                           1.932+/-0.053            1.991+/-0.081
# a                       0.05125+/-0.00103        0.05150+/-0.00034
# T_c               2454592.80154+/-0.00050  2454577.85806+/-0.00027
# b                                     ---        0.401+0.059-0.077
# RpRs                      0.1255+/-0.0007                      ---
# delta                                 ---            1.696+/-0.026
# transit_duration                      ---            4.392+/-0.041
# w                                     ---                    -70.6
# a/R*                 6.9638+0.0884-0.0862                      ---
# colour                            #bcbd22                  #17becf
#
#                            Anderson et al. 2010     Alderson et al. 2022  \
# Parameter
# e                             0.129+0.106-0.068                      ---
# i                                  87.8+2.0-1.0                      ---
# P                 3.7354417+0.0000072-0.0000073  3.73548546+/-0.00000027
# R                                1.74+0.26-0.23                      ---
# a                           0.051+0.0017-0.0018                      ---
# T_c                     2454559.18102+/-0.00028                      ---
# b                                           ---                      ---
# RpRs                                        ---                      ---
# delta                         1.672+0.029-0.035                      ---
# transit_duration           4.3728+0.0456-0.0552                      ---
# w                                    290+106-16                      ---
# a/R*                                        ---                      ---
# colour                                        g                        m
#
#                                                             Model A  \
# Parameter
# e                                                               ---
# i                 88.26186724077056+0.8517547512023071-1.0684883...
# P                 3.7353949699236395+0.00012754633562384043-0.00...
# R                                                               ---
# a                                                               ---
# T_c                                                             ---
# b                                                               ---
# RpRs              0.12053255948195171+0.0004945013872587195-0.00...
# delta                                                           ---
# transit_duration                                                ---
# w                                                               ---
# a/R*              7.377730002496927+0.21106325142519733-0.154211...
# colour                          (0.650746, 0.125309, 0.595617, 1.0)
#
#                                                             Model B  \
# Parameter
# e                                                               ---
# i                 87.42096806870872+0.3995554192736961-0.4857581...
# P                          3.7354848561896956+0.00000162-0.00000166
# R                                                               ---
# a                                                               ---
# T_c                                                             ---
# b                                                               ---
# RpRs              0.12147588016957986+0.0003907017476803415-0.00...
# delta                                                           ---
# transit_duration                                                ---
# w                                                               ---
# a/R*              7.16077405519621+0.11950623348097089-0.1293468...
# colour                          (0.798216, 0.280197, 0.469538, 1.0)
#
#                                                             Model C  \
# Parameter
# e                                                               ---
# i                 88.05242038422188+0.8237098425502438-1.0511485...
# P                           3.735457546163345+0.00005353-0.00006277
# R                                                               ---
# a                                                               ---
# T_c                                                             ---
# b                                                               ---
# RpRs              0.12132331355382717+0.0009057218589828414-0.00...
# delta                                                           ---
# transit_duration                                                ---
# w                                                               ---
# a/R*              7.309401355606358+0.21775645687941125-0.181765...
# colour                           (0.907365, 0.434524, 0.35297, 1.0)
#
#                                                             Model D
# Parameter
# e                                                               ---
# i                 87.30852050543098+0.39644874320137546-0.446981...
# P                       3.735484553218816+0.0000018351-0.0000018212
# R                                                               ---
# a                                                               ---
# T_c                                                             ---
# b                                                               ---
# RpRs              0.12217592094892667+0.0005177504782353098-0.00...
# delta                                                           ---
# transit_duration                                                ---
# w                                                               ---
# a/R*              7.115132869990389+0.12153948281163807-0.123589...
# colour                          (0.979233, 0.607532, 0.238013, 1.0)

# %%
df_ref_list = df.columns

df_e_list = df.loc['e'] #Eccentricty row
df_i_list = df.loc['i'] #Orbtial inclination row
df_P_list = df.loc['P'] #Orbtial period row
df_R_list = df.loc['R'] #Planetary radius row
df_a_list = df.loc['a'] #Semi-major axis row
df_b_list = df.loc['b'] #Impact parameter row
df_RpRs_list = df.loc['RpRs'] #R_p/R_star row
df_w_list = df.loc['w'] #
df_color = df.loc['colour'] #Colours
df_T_c_list = df.loc['T_c']
df_transit_duration_list = df.loc['transit_duration']
df_a_Rs_list = df.loc['a/R*']

e_list, e_ref_list = read_df_params(df_e_list, df_ref_list)
i_list, i_ref_list = read_df_params(df_i_list, df_ref_list)
P_list, P_ref_list = read_df_params(df_P_list, df_ref_list)
R_list, R_ref_list = read_df_params(df_R_list, df_ref_list)
a_list, a_ref_list = read_df_params(df_a_list, df_ref_list)
b_list, b_ref_list = read_df_params(df_b_list, df_ref_list)
RpRs_list, RpRs_ref_list = read_df_params(df_RpRs_list, df_ref_list)
T_c_list, T_c_ref_list = read_df_params(df_T_c_list, df_ref_list)
transit_duration_list, transit_duration_ref_list = read_df_params(df_transit_duration_list, df_ref_list)
a_Rs_list, a_Rs_ref_list = read_df_params(df_a_Rs_list, df_ref_list)

# %%
obj_mask = [True, True, False, False, False, False, True, True, False, False, False, True]
# obj_mask = [True, True, False, False, False, False, True, True, True, True, True, True]
#obj_mask = [True, True, False, False, False, False, True, True, True, True, True, True]
fontsize = 14
fig, ax = plt.subplots(1, figsize=(6, 4))

# x = np.linspace(3.7354775, 3.73549, 500)

# x_list = [, , , , ]
for P_obj, author, mask in zip(P_list, P_ref_list, obj_mask):
    if mask == True:
        mu, upper, lower = P_obj
        sigma = max(abs(upper), abs(lower))
        if sigma > 0:
            colour = df[author]['colour']
            if len(list(colour)) > 7:
                colour = tuple(map(float, df[author]['colour'][1:-1].split(', ')))
            if author == "Alderson et al. 2022":
                colour = "#1f77b4"
                x = np.linspace(3.73547, 3.73549, 500)
            elif author == "Patel & Espinoza 2022":
                colour = "#8c564b"
                x = np.linspace(3.73541, 3.73546, 500)
            elif author == "Ivshina & Winn 2022":
                x = np.linspace(3.73547, 3.73549, 500)
            elif author == "Anderson et al. 2010":
                colour = "#bcbd22"
                x = np.linspace(3.73541, 3.73547, 500)
            elif author == "Model D":
                author = "This work"
                x = np.linspace(3.73547, 3.73549, 500)
            plt.plot(x, stats.norm.pdf(x, mu, sigma), label=author, lw=2, color=colour)

x = np.linspace(3.73541, 3.73549, 1000)
ax.set_xlim(min(x), max(x)-0.0000001)
ax.set_ylim(0, 1.5E6)

ax.xaxis.set_minor_locator(tck.AutoMinorLocator())

ax.set_xlabel("Period (days)", size=fontsize)
ax.set_ylabel("Probability Density", size=fontsize)

ax.xaxis.set_tick_params(labelsize=fontsize)
ax.yaxis.set_tick_params(labelsize=fontsize)


ax.legend(loc='upper left', fontsize=fontsize)
plt.show()

#Same graph seen in https://doi.org/10.1093/mnras/stac661

# %%
fig, ax = plt.subplots(1, figsize=(8,6))

x = np.linspace(82, 90, 500)
for i_obj, author in zip(i_list, i_ref_list):
    mu, upper, lower = i_obj
    sigma = max(abs(upper), abs(lower))
    if sigma > 0:
        colour = df[author]['colour']
        if len(list(colour)) > 7:
            colour = tuple(map(float, df[author]['colour'][1:-1].split(', ')))
        plt.plot(x, stats.norm.pdf(x, mu, sigma), label=author, color=colour)

plt.xlabel(r"Orbital Inclination $i$ (deg)")
plt.ylabel("Probability Density")


ax.legend()
ax.xaxis.set_minor_locator(tck.AutoMinorLocator())

plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(8,6))

x = np.linspace(0.11, 0.14, 500)
for RpRs_obj, author in zip(RpRs_list, RpRs_ref_list):
    mu, upper, lower = RpRs_obj
    sigma = max(abs(upper), abs(lower))
    if sigma > 0:
        colour = df[author]['colour']
        if len(list(colour)) > 7:
            colour = tuple(map(float, df[author]['colour'][1:-1].split(', ')))
        plt.plot(x, stats.norm.pdf(x, mu, sigma), label=author, color=colour)

plt.xlabel(r'Planet-Star radius ratio $R_{p}/R_{*}$')
plt.ylabel("Probability Density")

ax.legend()
ax.xaxis.set_minor_locator(tck.AutoMinorLocator())

plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(8,6))

x = np.linspace(6, 8, 500)
for i_obj, author in zip(a_Rs_list, a_Rs_ref_list):
    mu, upper, lower = i_obj
    sigma = max(abs(upper), abs(lower))
    if sigma > 0:
        colour = df[author]['colour']
        if len(list(colour)) > 7:
            colour = tuple(map(float, df[author]['colour'][1:-1].split(', ')))
        plt.plot(x, stats.norm.pdf(x, mu, sigma), label=author, color=colour)

plt.xlabel(r"$a/R_{*}$")
plt.ylabel("Probability Density")

ax.legend()
ax.xaxis.set_minor_locator(tck.AutoMinorLocator())

plt.show()
