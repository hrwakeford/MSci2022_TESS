# %%
import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as tck

import pandas as pd
import pickle

# %%
"""
WASP-17b
"""
filename = r"C:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Transit_fitting\WASP_17b\gp_batman_model\WASP_17b_flat_samples.p"
with open(filename, "rb") as f:
    WASP_17b_flat_samples = pickle.load(f)
f.close()

#batman model
WASP_17b_model_T0 = np.percentile(WASP_17b_flat_samples[:, 0], 50) #Mid-transit time (Days)
WASP_17b_model_Rp = np.percentile(WASP_17b_flat_samples[:, 1], 50) #Rp/Rs
WASP_17b_model_per = np.percentile(WASP_17b_flat_samples[:, 2], 50) #Orbital period (Days)
WASP_17b_model_inc = np.percentile(WASP_17b_flat_samples[:, 3], 50) #Orbital inclination (Deg)
WASP_17b_model_a = np.percentile(WASP_17b_flat_samples[:, 4], 50) #a/R*

WASP_17b_model_Rp_error = np.diff(np.percentile(WASP_17b_flat_samples[:, 1], [16, 50, 84]))

#GP model
WASP_17b_model_sigma = np.percentile(WASP_17b_flat_samples[:, 5], 50) #amplitude
WASP_17b_model_sigma_error = np.diff(np.percentile(WASP_17b_flat_samples[:, 5], [16, 50, 84]))
WASP_17b_model_rho = np.percentile(WASP_17b_flat_samples[:, 6], 50) #time scale
WASP_17b_model_rho_error = np.diff(np.percentile(WASP_17b_flat_samples[:, 6], [16, 50, 84]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Transit_fitting\Figures\amplitude_vs_transit_depth.ipynb Cell 2 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Transit_fitting/Figures/amplitude_vs_transit_depth.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> """
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Transit_fitting/Figures/amplitude_vs_transit_depth.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> WASP-17b
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Transit_fitting/Figures/amplitude_vs_transit_depth.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> """
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Transit_fitting/Figures/amplitude_vs_transit_depth.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> filename = r"C:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Transit_fitting\WASP_17b\gp_batman_model\WASP_17b_flat_samples.p"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Transit_fitting/Figures/amplitude_vs_transit_depth.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> with open(filename, "rb") as f:
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Transit_fitting/Figures/amplitude_vs_transit_depth.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>     WASP_17b_flat_samples = pickle.load(f)
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Transit_fitting/Figures/amplitude_vs_transit_depth.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Student\\OneDrive\\MSci project\\MSci2022_TESS\\Transit_fitting\\WASP_17b\\gp_batman_model\\WASP_17b_flat_samples.p'

# %%
"""
WASP-39b
"""
filename = r"C:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Transit_fitting\WASP_39b\gp_batman_model\WASP_39b_gp_batman_flat_samples.p"
with open(filename, "rb") as f:
    WASP_39b_flat_samples = pickle.load(f)
f.close()

#batman model
WASP_39b_model_T0 = np.percentile(WASP_39b_flat_samples[:, 0], 50) #Mid-transit time (Days)
WASP_39b_model_Rp = np.percentile(WASP_39b_flat_samples[:, 1], 50) #Rp/Rs
WASP_39b_model_per = np.percentile(WASP_39b_flat_samples[:, 2], 50) #Orbital period (Days)
WASP_39b_model_inc = np.percentile(WASP_17b_flat_samples[:, 3], 50) #Orbital inclination (Deg)
WASP_39b_model_a = np.percentile(WASP_39b_flat_samples[:, 4], 50) #a/R*

WASP_39b_model_Rp_error = np.diff(np.percentile(WASP_39b_flat_samples[:, 1], [16, 50, 84]))

#GP model
WASP_39b_model_sigma = np.percentile(WASP_39b_flat_samples[:, 5], 50) #amplitude
WASP_39b_model_sigma_error = np.diff(np.percentile(WASP_39b_flat_samples[:, 5], [16, 50, 84]))
WASP_39b_model_rho = np.percentile(WASP_39b_flat_samples[:, 6], 50) #time scale
WASP_39b_model_rho_error = np.diff(np.percentile(WASP_39b_flat_samples[:, 6], [16, 50, 84]))

# %%
"""
HAT_P_26b
"""
filename = r"C:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Transit_fitting\HAT_P_26b\gp_batman_model\free_ecc\HAT_P_26b_free_ecc_gp_batman_flat_samples.p"
with open(filename, "rb") as f:
    HAT_P_26b_flat_samples = pickle.load(f)
f.close()

#batman model
HAT_P_26b_model_T0 = np.percentile(HAT_P_26b_flat_samples[:, 0], 50) #Mid-transit time (Days)
HAT_P_26b_model_Rp = np.percentile(HAT_P_26b_flat_samples[:, 1], 50) #Rp/Rs
HAT_P_26b_model_per = np.percentile(HAT_P_26b_flat_samples[:, 2], 50) #Orbital period (Days)
HAT_P_26b_model_inc = np.percentile(HAT_P_26b_flat_samples[:, 3], 50) #Orbital inclination (Deg)
HAT_P_26b_model_a = np.percentile(HAT_P_26b_flat_samples[:, 4], 50) #a/R*
HAT_P_26b_model_ecc = np.percentile(HAT_P_26b_flat_samples[:, 5], 50) #Eccentricity

HAT_P_26b_model_Rp_error = np.diff(np.percentile(HAT_P_26b_flat_samples[:, 1], [16, 50, 84]))

#GP model
HAT_P_26b_model_sigma = np.percentile(HAT_P_26b_flat_samples[:, 6], 50) #amplitude
HAT_P_26b_model_sigma_error = np.diff(np.percentile(HAT_P_26b_flat_samples[:, 6], [16, 50, 84]))
HAT_P_26b_model_rho = np.percentile(HAT_P_26b_flat_samples[:, 7], 50) #time scale
HAT_P_26b_model_rho_error = np.diff(np.percentile(HAT_P_26b_flat_samples[:, 7], [16, 50, 84]))

# %%
"""
HAT_P_32b
"""
filename = r"C:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Transit_fitting\HAT_P_32b\gp_batman_model\free_ecc\HAT_P_32b_free_ecc_gp_batman_flat_samples.p"
with open(filename, "rb") as f:
    HAT_P_32b_flat_samples = pickle.load(f)
f.close()

#batman model
HAT_P_32b_model_T0 = np.percentile(HAT_P_32b_flat_samples[:, 0], 50) #Mid-transit time (Days)
HAT_P_32b_model_Rp = np.percentile(HAT_P_32b_flat_samples[:, 1], 50) #Rp/Rs
HAT_P_32b_model_per = np.percentile(HAT_P_32b_flat_samples[:, 2], 50) #Orbital period (Days)
HAT_P_32b_model_inc = np.percentile(HAT_P_32b_flat_samples[:, 3], 50) #Orbital inclination (Deg)
HAT_P_32b_model_a = np.percentile(HAT_P_32b_flat_samples[:, 4], 50) #a/R*
HAT_P_32b_model_ecc = np.percentile(HAT_P_32b_flat_samples[:, 5], 50) #Eccentricity

HAT_P_32b_model_Rp_error = np.diff(np.percentile(HAT_P_32b_flat_samples[:, 1], [16, 50, 84]))

#GP model
HAT_P_32b_model_sigma = np.percentile(HAT_P_32b_flat_samples[:, 6], 50) #amplitude
HAT_P_32b_model_sigma_error = np.diff(np.percentile(HAT_P_32b_flat_samples[:, 6], [16, 50, 84]))
HAT_P_32b_model_rho = np.percentile(HAT_P_32b_flat_samples[:, 7], 50) #time scale
HAT_P_32b_model_rho_error = np.diff(np.percentile(HAT_P_32b_flat_samples[:, 7], [16, 50, 84]))

# %%
labels = ["WASP-17b", "WASP-39b", "HAT-P-26b", "HAT-P-32b"]
markers = ["o", "s", "^", "D"]

Rp_list = [WASP_17b_model_Rp, WASP_39b_model_Rp, HAT_P_26b_model_Rp, HAT_P_32b_model_Rp]
Rp_errors = [WASP_17b_model_Rp_error, WASP_39b_model_Rp_error, HAT_P_26b_model_Rp_error, HAT_P_32b_model_Rp_error]
Rp_errors_list = [max(abs(err1), abs(err2)) for err1, err2 in Rp_errors]

transit_depth_list = np.power(Rp_list, 2)
transit_depth_errors_list = np.divide(Rp_errors_list, Rp_list) * transit_depth_list

sigma_list = [WASP_17b_model_sigma, WASP_39b_model_sigma, HAT_P_26b_model_sigma, HAT_P_32b_model_sigma]
sigma_errors = [WASP_17b_model_sigma_error, WASP_39b_model_sigma_error, HAT_P_26b_model_sigma_error, HAT_P_32b_model_sigma_error]
sigma_error_list = [max(abs(err1), abs(err2)) for err1, err2 in sigma_errors]

rho_list = [WASP_17b_model_rho, WASP_39b_model_rho, HAT_P_26b_model_rho, HAT_P_32b_model_rho]
rho_errors = [WASP_17b_model_rho_error, WASP_39b_model_rho_error, HAT_P_26b_model_rho_error, HAT_P_32b_model_rho_error]
rho_error_list = [max(abs(err1), abs(err2)) for err1, err2 in rho_errors]

# %%
"""
Rp/Rs vs Amplitude

"""

fontsize = 15

fig, ax = plt.subplots(1, figsize=(8,6))

for sigma, Rp, sigma_err, Rp_error, label, mark in zip(sigma_list, Rp_list, sigma_error_list, Rp_errors_list, labels, markers):
    ax.errorbar(sigma, Rp, xerr=sigma_err, yerr=Rp_error, fmt=".", ecolor="LightGrey", markersize=0, zorder=0)
    ax.scatter(sigma, Rp, label=label, marker=mark, zorder=10, s=40)


ax.set_xlabel("Amplitude $\\sigma$", size=fontsize)
ax.set_ylabel("$R_{p}/R_{*}$", size=fontsize)
ax.set_xlim([0, 0.0019])
ax.set_ylim([0.06, 0.155])

ax.xaxis.set_tick_params(labelsize=fontsize)
ax.yaxis.set_tick_params(labelsize=fontsize)

# Mirror y
axy = ax.twinx()
axy.set_ylim(ax.get_ylim())
axy.get_yaxis().set_ticklabels([])
axy.tick_params(which="both", direction="in")

# Mirror x
axx = ax.twiny()
axx.set_xlim(ax.get_xlim())
axx.get_xaxis().set_ticklabels([])
axx.tick_params(which="both", direction="in")

axx.xaxis.set_minor_locator(ticker.AutoMinorLocator())
axy.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.xaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.yaxis.set_minor_locator(ticker.AutoMinorLocator())

ax.legend(loc='lower right', prop={'size': fontsize})
plt.show()

# %%
"""
Transit depth vs amplitude

"""


fontsize = 15

fig, ax = plt.subplots(1, figsize=(8,6))

for sigma, td, sigma_err, td_err, label, mark in zip(sigma_list, transit_depth_list, sigma_error_list, transit_depth_errors_list, labels, markers):
    ax.errorbar(sigma, td, xerr=sigma_err, yerr=td_err, fmt=".", ecolor="LightGrey", markersize=0, zorder=0)
    ax.scatter(sigma, td, label=label, marker=mark, zorder=10, s=40)


ax.set_xlabel("Amplitude $\\sigma$", size=fontsize)
ax.set_ylabel("Transit depth", size=fontsize) # $\Delta F$
ax.set_xlim([0, 0.0017])
ax.set_ylim([0, 0.025])

ax.xaxis.set_tick_params(labelsize=fontsize)
ax.yaxis.set_tick_params(labelsize=fontsize)

# Mirror y
axy = ax.twinx()
axy.set_ylim(ax.get_ylim())
axy.get_yaxis().set_ticklabels([])
axy.tick_params(which="both", direction="in")

# Mirror x
axx = ax.twiny()
axx.set_xlim(ax.get_xlim())
axx.get_xaxis().set_ticklabels([])
axx.tick_params(which="both", direction="in")

axx.xaxis.set_minor_locator(ticker.AutoMinorLocator())
axy.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.xaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.yaxis.set_minor_locator(ticker.AutoMinorLocator())

ax.legend(loc='lower right', prop={'size': fontsize})
plt.show()

# %%
"""
Amplitude vs transit depth, rho

"""
fontsize = 15

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))

"""
Amplitude vs rho
"""
for sigma, rho, sigma_err, rho_error, label, mark in zip(sigma_list, rho_list, sigma_error_list, rho_error_list, labels, markers):
    ax1.errorbar(rho, sigma, xerr=rho_error, yerr= sigma_err, fmt=".", ecolor="LightGrey", markersize=0, zorder=0)
    ax1.scatter(rho, sigma, marker=mark, zorder=10, s=40)

ax1.set_ylabel("Amplitude $\\sigma$", size=fontsize)
ax1.set_xlabel("Timescale $\\rho$ (Days)", size=fontsize)
ax1.set_xlim([0, 3.9]) #Rho
ax1.set_ylim([0, 0.0029]) #Amplitude



ax1.xaxis.set_tick_params(labelsize=fontsize)
ax1.yaxis.set_tick_params(labelsize=fontsize)

# Mirror y
ax1y = ax1.twinx()
ax1y.set_ylim(ax1.get_ylim())
ax1y.get_yaxis().set_ticklabels([])
ax1y.tick_params(which="both", direction="in")

# Mirror x
ax1x = ax1.twiny()
ax1x.set_xlim(ax1.get_xlim())
ax1x.get_xaxis().set_ticklabels([])
ax1x.tick_params(which="both", direction="in")

ax1x.xaxis.set_minor_locator(ticker.AutoMinorLocator())
ax1y.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax1.xaxis.set_minor_locator(ticker.AutoMinorLocator())
ax1.yaxis.set_minor_locator(ticker.AutoMinorLocator())

"""
Amplitude vs transit depth
"""

for sigma, td, sigma_err, td_err, label, mark in zip(sigma_list, transit_depth_list, sigma_error_list, transit_depth_errors_list, labels, markers):
    ax2.errorbar(td, sigma, xerr=td_err, yerr=sigma_err, fmt=".", ecolor="LightGrey", markersize=0, zorder=0)
    ax2.scatter(td, sigma, label=label, marker=mark, zorder=10, s=40)


ax2.set_xlabel("Transit depth", size=fontsize) # $\Delta F$
ax2.set_xlim([0, 0.069]) #Transit depth
ax2.set_ylim(ax1.get_ylim()) #Amplitude
ax2.get_yaxis().set_ticklabels([])
ax2.tick_params(axis="y", which="both", direction="in")

ax2.xaxis.set_tick_params(labelsize=fontsize)
ax2.yaxis.set_tick_params(labelsize=fontsize)

# Mirror y
ax2y = ax2.twinx()
ax2y.set_ylim(ax2.get_ylim())
ax2y.get_yaxis().set_ticklabels([])
ax2y.tick_params(which="both", direction="in")

# Mirror x
ax2x = ax2.twiny()
ax2x.set_xlim(ax2.get_xlim())
ax2x.get_xaxis().set_ticklabels([])
ax2x.tick_params(which="both", direction="in")

ax2x.xaxis.set_minor_locator(ticker.AutoMinorLocator())
ax2y.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax2.xaxis.set_minor_locator(ticker.AutoMinorLocator())
ax2.yaxis.set_minor_locator(ticker.AutoMinorLocator())

plt.subplots_adjust(wspace=0)
plt.show()

# %%
sigma_percent_list = np.multiply(sigma_list, 100)
sigma_percent_error_list = np.multiply(np.divide(sigma_error_list, sigma_list), sigma_percent_list)

transit_depth_percent_list = np.multiply(transit_depth_list, 100)
transit_depth_percent_errors_list = np.multiply(np.divide(transit_depth_errors_list, transit_depth_list), 100)

# %%
# """
# As percentages
# Amplitude vs transit depth, rho

# """
# fontsize = 15

# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))

# """
# Amplitude vs rho
# """
# for sigma, rho, sigma_err, rho_error, label, mark in zip(sigma_percent_list, rho_list, sigma_percent_error_list, rho_error_list, labels, markers):
#     ax1.errorbar(rho, sigma, xerr=rho_error, yerr= sigma_err, fmt=".", ecolor="LightGrey", markersize=0, zorder=0)
#     ax1.scatter(rho, sigma, marker=mark, zorder=10, s=40)

# ax1.set_ylabel("Amplitude $\\sigma$ (%)", size=fontsize)
# ax1.set_xlabel("Timescale $\\rho$ (days)", size=fontsize)
# ax1.set_xlim([0, 2.35]) #Rho
# ax1.set_ylim([0, 0.17]) #Amplitude



# ax1.xaxis.set_tick_params(labelsize=fontsize)
# ax1.yaxis.set_tick_params(labelsize=fontsize)

# # Mirror y
# ax1y = ax1.twinx()
# ax1y.set_ylim(ax1.get_ylim())
# ax1y.get_yaxis().set_ticklabels([])
# ax1y.tick_params(which="both", direction="in")

# # Mirror x
# ax1x = ax1.twiny()
# ax1x.set_xlim(ax1.get_xlim())
# ax1x.get_xaxis().set_ticklabels([])
# ax1x.tick_params(which="both", direction="in")

# ax1x.xaxis.set_minor_locator(ticker.AutoMinorLocator())
# ax1y.yaxis.set_minor_locator(ticker.AutoMinorLocator())
# ax1.xaxis.set_minor_locator(ticker.AutoMinorLocator())
# ax1.yaxis.set_minor_locator(ticker.AutoMinorLocator())

# """
# Amplitude vs transit depth
# """

# for sigma, td, sigma_err, td_err, label, mark in zip(sigma_percent_list, transit_depth_percent_list, sigma_percent_error_list, transit_depth_percent_errors_list, labels, markers):
#     ax2.errorbar(td, sigma, xerr=td_err, yerr=sigma_err, fmt=".", ecolor="LightGrey", markersize=0, zorder=0)
#     ax2.scatter(td, sigma, label=label, marker=mark, zorder=10, s=40)


# ax2.set_xlabel("Transit depth (%)", size=fontsize) # $\Delta F$
# ax2.set_xlim([0, 2.6]) #Transit depth
# ax2.set_ylim(ax1.get_ylim()) #Amplitude
# ax2.get_yaxis().set_ticklabels([])
# ax2.tick_params(axis="y", which="both", direction="in")

# ax2.xaxis.set_tick_params(labelsize=fontsize)
# ax2.yaxis.set_tick_params(labelsize=fontsize)

# # Mirror y
# ax2y = ax2.twinx()
# ax2y.set_ylim(ax2.get_ylim())
# ax2y.get_yaxis().set_ticklabels([])
# ax2y.tick_params(which="both", direction="in")

# # Mirror x
# ax2x = ax2.twiny()
# ax2x.set_xlim(ax2.get_xlim())
# ax2x.get_xaxis().set_ticklabels([])
# ax2x.tick_params(which="both", direction="in")

# ax2x.xaxis.set_minor_locator(ticker.AutoMinorLocator())
# ax2y.yaxis.set_minor_locator(ticker.AutoMinorLocator())
# ax2.xaxis.set_minor_locator(ticker.AutoMinorLocator())
# ax2.yaxis.set_minor_locator(ticker.AutoMinorLocator())

# ax2.legend(loc='upper left', prop={'size': fontsize})
# plt.subplots_adjust(wspace=0)
# plt.show()

# %% [markdown]
# The left panel shows the values for each planet Matern-3/2 kernel parameters; amplitude and timescale. The right panel shows a comparison between the amplitude and the transit depth.
#
#
# HAT-P-26 seems to be the quietest star out of the four exoplanetary systems, however the short baseline of data introduces a bias.
#
# WASP-39 has a short baseline of data which suggests bias that it is the noisist star in the list.
