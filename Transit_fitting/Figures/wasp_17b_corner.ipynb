# %%
import os
os.environ["OMP_NUM_THREADS"] = "4"

import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import corner
import batman
import emcee
import time
from multiprocessing import Pool
from IPython.display import display, Math
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as tck

from exotic_ld import StellarLimbDarkening

import pandas as pd
import pickle

import celerite2
from celerite2 import terms

# %%
filename = r"C:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Transit_fitting\WASP_17b\gp_batman_model\both_sectors\WASP_17b_flat_samples.p"
with open(filename, "rb") as f:
    flat_samples = pickle.load(f)
f.close()

# %%
guess = [1630.9, 0.1255, 3.73548546, 86.71, 6.997029892608971, 0.0005, 1]
#\\minus$ 2457000 (BTJD days)
labels = ["$T_{0}$", "$R_{p}/R_{*}$", "$P$ (days)", "$i$ ($\\degree$)", "$a/R_{*}$", "$\\sigma$", "$\\rho$"]
fig = corner.corner(flat_samples, labels=labels, truths=guess, show_titles=True, label_kwargs=dict(fontsize=12), title_kwargs=dict(fontsize=12))

labels = ["T_{0}", "R_{p}/R_{*}", "P", "i", "a/R_{*}", "\\sigma", "\\rho"]

ndim = len(labels)
axes = np.array(fig.axes).reshape((ndim, ndim))

#T_0
mcmc = np.percentile(flat_samples[:, 0], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.5f}_{{-{1:.5f}}}^{{+{2:.5f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[0])
axes[0, 0].set_title(title)

#R_{p}/R_{*}
mcmc = np.percentile(flat_samples[:, 1], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.5f}_{{-{1:.5f}}}^{{+{2:.5f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[1])
axes[1, 1].set_title(title)

#P
mcmc = np.percentile(flat_samples[:, 2], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.7f}_{{-{1:.7f}}}^{{+{2:.7f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[2])
axes[2, 2].set_title(title)

#i
mcmc = np.percentile(flat_samples[:, 3], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.2f}_{{-{1:.2f}}}^{{+{2:.2f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[3])
axes[3, 3].set_title(title)

#a/R*
mcmc = np.percentile(flat_samples[:, 4], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.2f}_{{-{1:.2f}}}^{{+{2:.2f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[4])
axes[4, 4].set_title(title)

#sigma
mcmc = np.percentile(flat_samples[:, 5], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.6f}_{{-{1:.6f}}}^{{+{2:.6f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[5])
axes[5, 5].set_title(title)

#rho
mcmc = np.percentile(flat_samples[:, 6], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{+{2:.3f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[6])
axes[6, 6].set_title(title)

plt.show()

# %%
model_T0 = np.percentile(flat_samples[:, 0], 50) #Mid-transit time (Days)
model_Rp = np.percentile(flat_samples[:, 1], 50) #Rp/Rs
model_per = np.percentile(flat_samples[:, 2], 50) #Orbital period (Days)
model_inc = np.percentile(flat_samples[:, 3], 50) #Orbital inclination (Deg)
model_a = np.percentile(flat_samples[:, 4], 50) #a/R*
# model_ecc = np.percentile(flat_samples[:, 5], 50) #Eccentricity
model_sigma = np.percentile(flat_samples[:, 5], 50)
model_rho = np.percentile(flat_samples[:, 6], 50)

# %%
guess = [1630.9, 0.1255, 3.73548546, 86.71, 6.997029892608971, 0.0005, 1]
median_list = [model_T0, model_Rp, model_per, model_inc, model_a, model_sigma, model_rho]
#\\minus$ 2457000 (BTJD days)
labels = ["$T_{0}$", "$R_{p}/R_{*}$", "$P$ (days)", "$i$ ($\\degree$)", "$a/R_{*}$", "$\\sigma$", "$\\rho$"]
fig = corner.corner(flat_samples, labels=labels, truths=median_list, quantiles=(0.16, 0.84), show_titles=True, label_kwargs=dict(fontsize=14), title_kwargs=dict(fontsize=14))

labels = ["T_{0}", "R_{p}/R_{*}", "P", "i", "a/R_{*}", "\\sigma", "\\rho"]

ndim = len(labels)
axes = np.array(fig.axes).reshape((ndim, ndim))

#T_0
mcmc = np.percentile(flat_samples[:, 0], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.5f}_{{-{1:.5f}}}^{{+{2:.5f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[0])
axes[0, 0].set_title(title)

#R_{p}/R_{*}
mcmc = np.percentile(flat_samples[:, 1], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.5f}_{{-{1:.5f}}}^{{+{2:.5f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[1])
axes[1, 1].set_title(title)

#P
mcmc = np.percentile(flat_samples[:, 2], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.7f}_{{-{1:.7f}}}^{{+{2:.7f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[2])
axes[2, 2].set_title(title)

#i
mcmc = np.percentile(flat_samples[:, 3], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.2f}_{{-{1:.2f}}}^{{+{2:.2f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[3])
axes[3, 3].set_title(title)

#a/R*
mcmc = np.percentile(flat_samples[:, 4], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.2f}_{{-{1:.2f}}}^{{+{2:.2f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[4])
axes[4, 4].set_title(title)

#sigma
mcmc = np.percentile(flat_samples[:, 5], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.6f}_{{-{1:.6f}}}^{{+{2:.6f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[5])
axes[5, 5].set_title(title)

#rho
mcmc = np.percentile(flat_samples[:, 6], [16, 50, 84])
q = np.diff(mcmc)
title = r"${{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{+{2:.3f}}}$"
title = title.format(mcmc[1], q[0], q[1], labels[6])
axes[6, 6].set_title(title)

plt.show()
