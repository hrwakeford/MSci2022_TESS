# %%
import os
os.environ["OMP_NUM_THREADS"] = "4"

import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import corner
import batman
import emcee
import time
from multiprocessing import Pool
from IPython.display import display, Math
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as tck

from exotic_ld import StellarLimbDarkening

import pandas as pd
import pickle

import celerite2
from celerite2 import terms

# %%
TIC = 'TIC 66818296' #WASP-17 / TIC 66818296

search_result = lk.search_lightcurve(
    target=TIC,
    mission='TESS', author='SPOC')
print("trying to download")
lc_collection = search_result.download_all()
print("Search done")

lc = lc_collection[0] #Sector 12

lc = lc.remove_nans()
lc = lc.normalize()
# Out:
# trying to download
# Search done

# %%
lc
# Out:
# <TessLightCurve length=13936 LABEL="TIC 66818296" SECTOR=12 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                                   ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1628.9527366213874  9.9146342e-01 ...  4.0939126e-02  2.0365320e-01
# 1628.9541255101508  9.9583793e-01 ...  2.5400141e-02  2.1769401e-01
#  1628.955514398915  9.9091458e-01 ...  3.9708838e-02  2.1558438e-01
# 1628.9569032876798  9.9025726e-01 ...  5.3074531e-02  1.9718842e-01
# 1628.9582921764436  9.9405742e-01 ...  4.2726278e-02  2.0543911e-01
#  1628.959681065207  9.9572426e-01 ...  2.1659279e-02  2.1886539e-01
#  1628.961069953971  9.9142510e-01 ...  3.9847802e-02  2.0756216e-01
#  1628.962458842735  9.9342662e-01 ...  3.7096344e-02  2.0781381e-01
# 1628.9638477314988  9.9085009e-01 ...  4.2317994e-02  2.1254507e-01
#                ...            ... ...            ...            ...
# 1652.8842412266986  1.0013599e+00 ...  7.0131570e-02 -6.3381739e-02
# 1652.8856300647049  1.0039089e+00 ...  7.1430922e-02 -5.9996147e-02
# 1652.8870189027111  1.0052422e+00 ...  6.2911309e-02 -6.4712152e-02
# 1652.8884077407179  1.0015087e+00 ...  6.6857502e-02 -6.2283788e-02
# 1652.8897965791898  1.0005902e+00 ...  7.3385313e-02 -5.5208735e-02
#  1652.891185417197  1.0026343e+00 ...  7.0239693e-02 -6.5530986e-02
# 1652.8925742552046  9.9932802e-01 ...  6.9010720e-02 -6.3583061e-02
# 1652.8939630932114  9.9952310e-01 ...  6.5565862e-02 -6.4391859e-02
# 1652.8953519312176  1.0016207e+00 ...  7.4729733e-02 -5.6722909e-02
#  1652.896740769224  9.9703723e-01 ...  6.6471055e-02 -5.7022590e-02

# %%
t = np.array(lc.time.btjd)
flux_data = np.array(lc.flux)
yerrs = np.array(lc.flux_err)

# %%
fig, ax = plt.subplots(1, figsize=(8,6))
plt.errorbar(t, flux_data, yerrs, fmt='.', color='Black', ecolor='LightGrey')


plt.ylabel("Normalised flux", size=17)
plt.xlabel("Time - 2457000 (BTJD days)", size=17)

ax.xaxis.set_tick_params(labelsize=17)
ax.yaxis.set_tick_params(labelsize=17)

ax.xaxis.set_minor_locator(tck.AutoMinorLocator())
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())

plt.show()

# %%
def set_params(params, yerrs):
    _sigma, _rho = params
    kernel = terms.Matern32Term(sigma = _sigma, rho  = _rho)
    gp = celerite2.GaussianProcess(kernel, mean=0.0,)
    gp.compute(t, yerr=yerrs, quiet=True)

    return gp

# %%
def log_likelihood(prior_params, flux_data, yerrs):
    
    gp = set_params(prior_params, yerrs)

    prob = gp.log_likelihood(flux_data)
    return prob


def log_prior(prior_params):
    _sigma, _rho = prior_params

    prob = 0.0
    if _sigma < 0:
        prob += -np.inf
        return prob
    
    if _rho < 0:
        prob += -np.inf
        return prob
    
    return prob


def log_prob(prior_params, flux_data, yerrs):
    lp = log_prior(prior_params)
    if (np.isinf(lp) == True):
        return -np.inf

    return log_likelihood(prior_params, flux_data, yerrs) + lp

# %%
guess = [100, 1000000] #Sigma, rho

coords = guess + 1E-8 * np.random.randn(20, len(guess))


with Pool() as pool:
    start_time = time.time()
    print("Start:       {}".format(time.ctime(int(start_time))))
    sampler = emcee.EnsembleSampler(coords.shape[0], coords.shape[1], log_prob, args=(flux_data, yerrs))
    sampler.run_mcmc(coords, 100000, progress=True)
    end_time = time.time()
    execution_time = (end_time - start_time)
    print("End:         {}".format(time.ctime(int(end_time))))
    print("Time taken:  {:.2f} s".format(execution_time))
# Out:
# Start:       Fri Feb  3 16:54:11 2023
#  58%|█████▊    | 57854/100000 [50:41<36:37, 19.18it/s]  Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/tmp/ipykernel_121456/4088700014.py", line 29, in log_prob
#     return log_likelihood(prior_params, flux_data, yerrs) + lp
#   File "/tmp/ipykernel_121456/4088700014.py", line 5, in log_likelihood
#     prob = gp.log_likelihood(flux_data)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/celerite2/core.py", line 427, in log_likelihood
#     return self._norm - 0.5 * self._do_norm(y - self._mean_value)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/celerite2/numpy.py", line 106, in _do_norm
#     self._t, self._c, self._U, self._W, alpha, alpha
# AttributeError: 'GaussianProcess' object has no attribute '_W'
#  58%|█████▊    | 57855/100000 [50:41<36:55, 19.02it/s]
# emcee: Exception while calling your likelihood function:
#   params: [  19057.95205383 1796738.9760512 ]
#   args: (array([0.9914634 , 0.9958379 , 0.9909146 , ..., 0.9995231 , 1.0016207 ,
#        0.99703723], dtype=float32), array([0.00222942, 0.00223049, 0.00222878, ..., 0.00189515, 0.00189635,
#        0.00189532], dtype=float32))
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 10
#       8 print("Start:       {}".format(time.ctime(int(start_time))))
#       9 sampler = emcee.EnsembleSampler(coords.shape[0], coords.shape[1], log_prob, args=(flux_data, yerrs))
# ---> 10 sampler.run_mcmc(coords, 100000, progress=True)
#      11 end_time = time.time()
#      12 execution_time = (end_time - start_time)
#
# File ~/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/emcee/ensemble.py:443, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     440     initial_state = self._previous_state
#     442 results = None
# --> 443 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     444     pass
#     446 # Store so that the ``initial_state=None`` case will work
#
# File ~/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/emcee/ensemble.py:402, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     399 move = self._random.choice(self._moves, p=self._weights)
#     401 # Propose
# --> 402 state, accepted = move.propose(model, state)
#     403 state.random_state = self.random_state
#     405 if tune:
#
# File ~/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/emcee/moves/red_blue.py:93, in RedBlueMove.propose(self, model, state)
#      90 q, factors = self.get_proposal(s, c, model.random)
#      92 # Compute the lnprobs of the proposed position.
# ---> 93 new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      95 # Loop over the walkers and update them accordingly.
#      96 for i, (j, f, nlp) in enumerate(
#      97     zip(all_inds[S1], factors, new_log_probs)
#      98 ):
#
# File ~/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/emcee/ensemble.py:489, in EnsembleSampler.compute_log_prob(self, coords)
#     487     else:
#     488         map_func = map
# --> 489     results = list(map_func(self.log_prob_fn, p))
#     491 try:
#     492     log_prob = np.array([float(l[0]) for l in results])
#
# File ~/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/emcee/ensemble.py:624, in _FunctionWrapper.__call__(self, x)
#     622 def __call__(self, x):
#     623     try:
# --> 624         return self.f(x, *self.args, **self.kwargs)
#     625     except:  # pragma: no cover
#     626         import traceback
#
# Cell In[7], line 29, in log_prob(prior_params, flux_data, yerrs)
#      26 if (np.isinf(lp) == True):
#      27     return -np.inf
# ---> 29 return log_likelihood(prior_params, flux_data, yerrs) + lp
#
# Cell In[7], line 5, in log_likelihood(prior_params, flux_data, yerrs)
#       1 def log_likelihood(prior_params, flux_data, yerrs):
#       3     gp = set_params(prior_params, yerrs)
# ----> 5     prob = gp.log_likelihood(flux_data)
#       6     return prob
#
# File ~/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/celerite2/core.py:427, in BaseGaussianProcess.log_likelihood(self, y, inplace)
#     407 """Compute the marginalized likelihood of the GP model
#     408
#     409 The factorized matrix from the previous call to
#    (...)
#     424     ValueError: When the inputs are not valid (shape, number, etc.).
#     425 """
#     426 y = self._process_input(y, require_vector=True, inplace=inplace)
# --> 427 return self._norm - 0.5 * self._do_norm(y - self._mean_value)
#
# File ~/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/celerite2/numpy.py:106, in GaussianProcess._do_norm(self, y)
#     103 def _do_norm(self, y):
#     104     alpha = y[:, None]
#     105     alpha = driver.solve_lower(
# --> 106         self._t, self._c, self._U, self._W, alpha, alpha
#     107     )[:, 0]
#     108     return np.sum(alpha ** 2 / self._d)
#
# AttributeError: 'GaussianProcess' object has no attribute '_W'

# %%
samples = sampler.get_chain()
tau = sampler.get_autocorr_time()
print(tau)

# %%
burnin = int(2 * np.max(tau))
thin = int(0.5 * np.min(tau))
flat_samples = sampler.get_chain(discard=burnin, thin=thin, flat=True)
print(flat_samples.shape)
