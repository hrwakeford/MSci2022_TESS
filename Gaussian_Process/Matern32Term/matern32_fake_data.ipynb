# %%
import os
os.environ["OMP_NUM_THREADS"] = "4"

import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import corner
import batman
import emcee
import time
from multiprocessing import Pool
from IPython.display import display, Math
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as tck

from exotic_ld import StellarLimbDarkening

import pandas as pd
import pickle

import celerite2
from celerite2 import terms

# %%
np.random.seed(100)

# %%
#2 minute cadence = 720 samples in 1 day 

t = np.sort(np.append(
        np.random.uniform(0, 12, 100), 
        np.random.uniform(17, 30, 100),
    ))  # The input coordinates must be sorted
yerr = np.random.uniform(0.0001, 0.005, len(t))
y = (1 + 0.00001*np.sin(t + 6) + yerr * np.random.randn(len(t)))

true_t = np.linspace(0, 30, len(t))
true_y = (1 + 0.0000001*np.sin(true_t + 6) + yerr * np.random.randn(len(true_t)))

plt.plot(true_t, true_y, lw=1.5, alpha=0.3, color="r", zorder=0)
plt.errorbar(t, y, yerr=yerr, fmt=".", color="black", ecolor="LightGrey", capsize=0, zorder=100)
plt.xlabel("x [day]")
plt.ylabel("y")
_ = plt.title("simulated data")

# %%
def set_params(params, yerrs):
    _sigma, _rho = params
    kernel = terms.Matern32Term(sigma = _sigma, rho  = _rho)
    gp = celerite2.GaussianProcess(kernel, mean=0.0,)
    gp.compute(t, yerr=yerrs, quiet=True)

    return gp

# %%
def plot(parmas):

    gp = set_params(parmas, yerr)
    gp.compute(t, yerr=yerr)

    conditional = gp.condition(y, true_t)

    plt.plot(true_t, conditional.sample(), color="C1")
    plt.errorbar(t, y, yerr=yerr, fmt=".k", capsize=0)
    plt.ylim(0.95, 1.05)
    plt.xlabel("x [day]")
    plt.ylabel("y [ppm]")
    plt.show()

# %%
plot([100, 1000])

# %%
param_list = [[1, 1000000], [100, 1000000], [1000, 1000000]]

for params in param_list: 
    gp = set_params(params, yerr)
    gp.compute(t, yerr=yerr)

    conditional = gp.condition(y, true_t)
    label = "$\sigma$ %s, $\\rho$ %s" % (params[0], params[1]) 
    plt.plot(true_t, conditional.sample(), label=label)

plt.title("Varying $\sigma$")
plt.errorbar(t, y, yerr=yerr, fmt=".k", capsize=0)
plt.ylim(0.98, 1.02)
plt.xlabel("x [day]")
plt.ylabel("y [ppm]")
plt.legend()
plt.show()

# %%
param_list = [[100, 10000], [100, 100000], [100, 1000000], [100, 10000000]]

for params in param_list: 
    gp = set_params(params, yerr)
    gp.compute(t, yerr=yerr)

    conditional = gp.condition(y, true_t)
    label = "$\sigma$ %s, $\\rho$ %s" % (params[0], params[1]) 
    plt.plot(true_t, conditional.sample(), label=label)

plt.title("Varying $\\rho$")
plt.errorbar(t, y, yerr=yerr, fmt=".k", capsize=0)
plt.ylim(0.98, 1.02)
plt.xlabel("x [day]")
plt.ylabel("y [ppm]")
plt.legend()
plt.show()

# %%
def set_params(params, yerrs):
    _sigma, _rho = params
    kernel = terms.Matern32Term(sigma = _sigma, rho  = _rho)
    
    gp = celerite2.GaussianProcess(kernel, mean=0.0,)
    gp.compute(t, yerr=yerrs, quiet=True)

    return gp

# %%
def log_likelihood(prior_params, flux_data, yerrs):
    
    gp = set_params(prior_params, yerrs)

    prob = gp.log_likelihood(flux_data)
    return prob


def log_prior(prior_params):
    _sigma, _rho = prior_params

    prob = 0.0
    if _sigma < -1E6 or _sigma > 1E6:
        prob += -np.inf
        return prob
    
    if _rho < 0 or _rho > 1E6:
        prob += -np.inf
        return prob
    
    return prob


def log_prob(prior_params, flux_data, yerrs):
    lp = log_prior(prior_params)
    if (np.isinf(lp) == True):
        return -np.inf

    return log_likelihood(prior_params, flux_data, yerrs) + lp

# %%
guess = [100, 100000]

pos = guess + 1E-8 * np.random.randn(20, len(guess))
nwalkers, ndim = pos.shape


with Pool() as pool:
    start_time = time.time()
    print("Start:       {}".format(time.ctime(int(start_time))))
    sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob, args=(y, yerr))
    sampler.run_mcmc(pos, 10000, progress=True)

    end_time = time.time()
    execution_time = (end_time - start_time)
    print("End:         {}".format(time.ctime(int(end_time))))
    print("Time taken:  {:.2f} s".format(execution_time))
# Out:
# Start:       Tue Feb  7 11:54:38 2023
#   2%|▏         | 218/10000 [00:01<00:41, 233.86it/s]Traceback (most recent call last):
#   File "c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "C:\Users\Student\AppData\Local\Temp\ipykernel_2632\3345806500.py", line 29, in log_prob
#     return log_likelihood(prior_params, flux_data, yerrs) + lp
#   File "C:\Users\Student\AppData\Local\Temp\ipykernel_2632\3345806500.py", line 5, in log_likelihood
#     prob = gp.log_likelihood(flux_data)
#   File "c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\celerite2\core.py", line 427, in log_likelihood
#     return self._norm - 0.5 * self._do_norm(y - self._mean_value)
#   File "c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\celerite2\numpy.py", line 106, in _do_norm
#     self._t, self._c, self._U, self._W, alpha, alpha
# AttributeError: 'GaussianProcess' object has no attribute '_W'
#   2%|▏         | 224/10000 [00:01<00:50, 192.04it/s]
# emcee: Exception while calling your likelihood function:
#   params: [   4.83198772 -449.63442626]
#   args: (array([1.00343497, 1.00355151, 1.00402329, 0.9985526 , 1.00212121,
#        0.999524  , 1.00091496, 1.00043101, 1.0001127 , 1.00336211,
#        1.00797734, 0.99873415, 1.00019977, 1.0046863 , 0.99977116,
#        1.00302273, 1.00398596, 1.00025921, 0.99667823, 1.0004061 ,
#        1.00167249, 0.99872661, 0.99943607, 1.00080668, 1.0014107 ,
#        0.99937432, 0.99818857, 0.99854613, 0.99770069, 1.00193071,
#        0.99846158, 0.99637748, 1.0007858 , 1.00051007, 1.00962263,
#        0.99955617, 1.00089948, 1.00024435, 1.00037818, 1.00080366,
#        0.99978928, 0.99919148, 1.0000148 , 1.00199545, 0.99749623,
#        0.999409  , 0.99581679, 0.99989941, 1.00093036, 0.99868838,
#        1.00262757, 0.99929079, 1.0064246 , 0.99815528, 1.00138192,
#        0.99911648, 0.99991505, 1.00221593, 0.99952349, 0.99964079,
#        1.00082166, 1.00389035, 0.99948706, 1.00229714, 0.99118621,
#        1.00070916, 0.99747283, 1.00278923, 0.99851372, 1.00010672,
#        0.99414341, 1.00074672, 0.99928136, 1.01194984, 1.00051724,
#        0.99956911, 1.00075074, 0.99683288, 0.99883136, 1.00112917,
#        0.99015823, 1.00025041, 0.99931424, 1.00038541, 0.99923115,
#        1.00348984, 0.99949658, 0.99972971, 0.99843108, 0.99985641,
#        1.00000903, 1.00018569, 0.99454633, 1.00197264, 0.99905305,
#        0.99488423, 0.9997647 , 0.99807436, 1.0000423 , 0.99992916,
#        0.99983241, 1.00088688, 0.99873297, 1.00150339, 0.99500103,
#        1.00012193, 0.9993896 , 0.99933999, 1.0060151 , 0.99993838,
#        1.00012085, 1.00296286, 1.00527594, 0.99627863, 1.00276636,
#        0.99823929, 0.99497472, 1.00320253, 0.99882802, 1.00014185,
#        1.00041744, 1.00089134, 0.99982025, 0.99915779, 0.9994975 ,
#        0.00321193, 0.00122685, 0.00035091, 0.00023947, 0.00070195,
#        0.00117904, 0.00416221, 0.00149891, 0.00392721, 0.00257286,
#        0.0007784 , 0.00391238, 0.00461453, 0.00472079, 0.00355174,
#        0.00350019, 0.0027781 , 0.00190916, 0.00491409, 0.00042149,
#        0.00449862, 0.00139326, 0.00291493, 0.00261304, 0.00281694,
#        0.00327112, 0.00100882, 0.00143269, 0.00082735, 0.00024849,
#        0.00470235, 0.0017991 , 0.00063687, 0.0019538 , 0.00198199,
#        0.00336058, 0.00129801, 0.00334126, 0.00058262, 0.00294623,
#        0.00062364, 0.00278645, 0.00264678, 0.00155155, 0.00233307,
#        0.00028947, 0.00303511, 0.00010239, 0.00255889, 0.00255846]))
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Gaussian_Process\Matern32Term\matern32_fake_data.ipynb Cell 11 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> print("Start:       {}".format(time.ctime(int(start_time))))
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob, args=(y, yerr))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> sampler.run_mcmc(pos, 10000, progress=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> end_time = time.time()
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> execution_time = (end_time - start_time)
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\ensemble.py:443, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     440     initial_state = self._previous_state
#     442 results = None
# --> 443 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     444     pass
#     446 # Store so that the ``initial_state=None`` case will work
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\ensemble.py:402, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     399 move = self._random.choice(self._moves, p=self._weights)
#     401 # Propose
# --> 402 state, accepted = move.propose(model, state)
#     403 state.random_state = self.random_state
#     405 if tune:
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\moves\red_blue.py:93, in RedBlueMove.propose(self, model, state)
#      90 q, factors = self.get_proposal(s, c, model.random)
#      92 # Compute the lnprobs of the proposed position.
# ---> 93 new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      95 # Loop over the walkers and update them accordingly.
#      96 for i, (j, f, nlp) in enumerate(
#      97     zip(all_inds[S1], factors, new_log_probs)
#      98 ):
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\ensemble.py:489, in EnsembleSampler.compute_log_prob(self, coords)
#     487     else:
#     488         map_func = map
# --> 489     results = list(map_func(self.log_prob_fn, p))
#     491 try:
#     492     log_prob = np.array([float(l[0]) for l in results])
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\ensemble.py:624, in _FunctionWrapper.__call__(self, x)
#     622 def __call__(self, x):
#     623     try:
# --> 624         return self.f(x, *self.args, **self.kwargs)
#     625     except:  # pragma: no cover
#     626         import traceback
#
# c:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Gaussian_Process\Matern32Term\matern32_fake_data.ipynb Cell 11 in log_prob(prior_params, flux_data, yerrs)
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=25'>26</a> if (np.isinf(lp) == True):
#      <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a>     return -np.inf
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=28'>29</a> return log_likelihood(prior_params, flux_data, yerrs) + lp
#
# c:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Gaussian_Process\Matern32Term\matern32_fake_data.ipynb Cell 11 in log_likelihood(prior_params, flux_data, yerrs)
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> def log_likelihood(prior_params, flux_data, yerrs):
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     gp = set_params(prior_params, yerrs)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>     prob = gp.log_likelihood(flux_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a>     return prob
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\celerite2\core.py:427, in BaseGaussianProcess.log_likelihood(self, y, inplace)
#     407 """Compute the marginalized likelihood of the GP model
#     408
#     409 The factorized matrix from the previous call to
#    (...)
#     424     ValueError: When the inputs are not valid (shape, number, etc.).
#     425 """
#     426 y = self._process_input(y, require_vector=True, inplace=inplace)
# --> 427 return self._norm - 0.5 * self._do_norm(y - self._mean_value)
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\celerite2\numpy.py:106, in GaussianProcess._do_norm(self, y)
#     103 def _do_norm(self, y):
#     104     alpha = y[:, None]
#     105     alpha = driver.solve_lower(
# --> 106         self._t, self._c, self._U, self._W, alpha, alpha
#     107     )[:, 0]
#     108     return np.sum(alpha ** 2 / self._d)
#
# AttributeError: 'GaussianProcess' object has no attribute '_W'

# %%
samples = sampler.get_chain()
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# ---------------------------------------------------------------------------
# AutocorrError                             Traceback (most recent call last)
# c:\Users\Student\OneDrive\MSci project\MSci2022_TESS\Gaussian_Process\Matern32Term\matern32_fake_data.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> samples = sampler.get_chain()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> tau = sampler.get_autocorr_time()
#       <a href='vscode-notebook-cell:/c%3A/Users/Student/OneDrive/MSci%20project/MSci2022_TESS/Gaussian_Process/Matern32Term/matern32_fake_data.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> print(tau)
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\ensemble.py:605, in EnsembleSampler.get_autocorr_time(self, **kwargs)
#     604 def get_autocorr_time(self, **kwargs):
# --> 605     return self.backend.get_autocorr_time(**kwargs)
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\backends\backend.py:150, in Backend.get_autocorr_time(self, discard, thin, **kwargs)
#     131 """Compute an estimate of the autocorrelation time for each parameter
#     132
#     133 Args:
#    (...)
#     147
#     148 """
#     149 x = self.get_chain(discard=discard, thin=thin)
# --> 150 return thin * autocorr.integrated_time(x, **kwargs)
#
# File c:\Users\Student\anaconda3\envs\MSci_project\lib\site-packages\emcee\autocorr.py:112, in integrated_time(x, c, tol, quiet)
#     110     msg += "N/{0} = {1:.0f};\ntau: {2}".format(tol, n_t / tol, tau_est)
#     111     if not quiet:
# --> 112         raise AutocorrError(tau_est, msg)
#     113     logger.warning(msg)
#     115 return tau_est
#
# AutocorrError: The chain is shorter than 50 times the integrated autocorrelation time for 1 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 200;
# tau: [231.99762583 100.96258519]

# %%
fig, axes = plt.subplots(len(guess), figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["$\\sigma$", "$\\rho$"]

for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])

axes[-1].set_xlabel("step number")
plt.show()

# %%
burnin = int(2 * np.max(tau))
thin = int(0.5 * np.min(tau))
flat_samples = sampler.get_chain(discard=burnin, thin=thin, flat=True)
print(flat_samples.shape)
# Out:
# (3680, 2)

# %%
fig = corner.corner(
    flat_samples, labels=labels)
