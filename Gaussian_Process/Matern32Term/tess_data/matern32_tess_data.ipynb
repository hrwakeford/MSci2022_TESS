# %%
import os
os.environ["OMP_NUM_THREADS"] = "4"

import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import corner
import batman
import emcee
import time
from multiprocessing import Pool
from IPython.display import display, Math
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as tck

from exotic_ld import StellarLimbDarkening

import pandas as pd
import pickle

import celerite2
from celerite2 import terms

# %%
TIC = 'TIC 66818296' #WASP-17 / TIC 66818296

search_result = lk.search_lightcurve(
    target=TIC,
    mission='TESS', author='SPOC')
print("trying to download")
lc_collection = search_result.download_all()
print("Search done")
print(lc_collection)

lc = lc_collection.stitch(corrector_func=lambda x: x.
                          remove_nans().normalize(unit='unscaled'))
#Sector 12 and sector 38
lc = lc.remove_nans()
# Out:
# trying to download
# Search done
# LightCurveCollection of 2 objects:
#     0: <TessLightCurve LABEL="TIC 66818296" SECTOR=12 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 66818296" SECTOR=38 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lc
# Out:
# <TessLightCurve length=32188 LABEL="TIC 66818296" SECTOR=38 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                                   ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1628.9527366213874  9.9146342e-01 ...  4.0939126e-02  2.0365320e-01
# 1628.9541255101508  9.9583793e-01 ...  2.5400141e-02  2.1769401e-01
#  1628.955514398915  9.9091458e-01 ...  3.9708838e-02  2.1558438e-01
# 1628.9569032876798  9.9025726e-01 ...  5.3074531e-02  1.9718842e-01
# 1628.9582921764436  9.9405742e-01 ...  4.2726278e-02  2.0543911e-01
#  1628.959681065207  9.9572426e-01 ...  2.1659279e-02  2.1886539e-01
#  1628.961069953971  9.9142510e-01 ...  3.9847802e-02  2.0756216e-01
#  1628.962458842735  9.9342662e-01 ...  3.7096344e-02  2.0781381e-01
# 1628.9638477314988  9.9085009e-01 ...  4.2317994e-02  2.1254507e-01
#                ...            ... ...            ...            ...
# 2360.5441243211485  9.9800473e-01 ... -4.0721402e-02 -1.2793957e-01
# 2360.5455132112825  9.9706757e-01 ... -3.1029750e-02 -1.1463796e-01
#  2360.546902100951  9.9684072e-01 ... -2.9239954e-02 -1.2163924e-01
# 2360.5482909910857  9.9875683e-01 ... -3.2724239e-02 -1.2526417e-01
#  2360.549679880755  9.9811131e-01 ... -6.6930088e-03 -9.3329951e-02
#  2360.551068770889  9.9923408e-01 ... -3.3805996e-02 -1.1018278e-01
# 2360.5524576605576  9.9342787e-01 ... -4.1973919e-02 -1.3398527e-01
# 2360.5538465502273  9.9377340e-01 ... -2.7427465e-02 -1.1809707e-01
# 2360.5552354403626  9.9881291e-01 ... -2.9949540e-02 -1.0975430e-01
# 2360.5566243300314  1.0000453e+00 ... -3.8550492e-02 -1.1752584e-01

# %%
t = np.array(lc.time.btjd)
flux_data = np.array(lc.flux)
yerrs = np.array(lc.flux_err)

# %%
fig, ax = plt.subplots(1, figsize=(8,6))
plt.errorbar(t, flux_data, yerrs, fmt='.', color='Black', ecolor='LightGrey')


plt.ylabel("Normalised flux", size=17)
plt.xlabel("Time - 2457000 (BTJD days)", size=17)

ax.xaxis.set_tick_params(labelsize=17)
ax.yaxis.set_tick_params(labelsize=17)

ax.xaxis.set_minor_locator(tck.AutoMinorLocator())
ax.yaxis.set_minor_locator(tck.AutoMinorLocator())

plt.show()

# %%
def set_params(params, yerrs):
    _sigma, _rho = params
    kernel = terms.Matern32Term(sigma = _sigma, rho  = _rho)
    gp = celerite2.GaussianProcess(kernel, mean=0.0,)
    gp.compute(t, yerr=yerrs, quiet=True)

    return gp

# %%
def log_likelihood(prior_params, flux_data, yerrs):
    
    gp = set_params(prior_params, yerrs)

    prob = gp.log_likelihood(flux_data)
    return prob


def log_prior(prior_params):
    _sigma, _rho = prior_params

    prob = 0.0
    if _sigma < 0 or _sigma > 1E5:
        prob += -np.inf
        return prob
    
    if _rho < 0 or _rho > 1E5:
        prob += -np.inf
        return prob
    
    return prob


def log_prob(prior_params, flux_data, yerrs):
    lp = log_prior(prior_params)
    if (np.isinf(lp) == True):
        return -np.inf

    return log_likelihood(prior_params, flux_data, yerrs) + lp

# %%
guess = [100, 1000] #Sigma, rho

pos = guess + 1E-8 * np.random.randn(20, len(guess))

nwalkers, ndim = pos.shape

filename = "matern32_tess_data.h5"
backend = emcee.backends.HDFBackend(filename)
backend.reset(nwalkers, ndim)

with Pool() as pool:
    start_time = time.time()
    print("Start:       {}".format(time.ctime(int(start_time))))
    
    sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob, args=(flux_data, yerrs))
    sampler.run_mcmc(pos, 100000, progress=True)
    
    end_time = time.time()
    execution_time = (end_time - start_time)
    print("End:         {}".format(time.ctime(int(end_time))))
    print("Time taken:  {:.2f} s".format(execution_time))
# Out:
# Start:       Wed Feb  8 15:37:12 2023
#  42%|████▏     | 42344/100000 [1:05:16<1:26:11, 11.15it/s]Process ForkPoolWorker-36:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-54:
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/tmp/ipykernel_216061/3428204298.py", line 29, in log_prob
#     return log_likelihood(prior_params, flux_data, yerrs) + lp
#   File "/tmp/ipykernel_216061/3428204298.py", line 5, in log_likelihood
#     prob = gp.log_likelihood(flux_data)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/celerite2/core.py", line 427, in log_likelihood
#     return self._norm - 0.5 * self._do_norm(y - self._mean_value)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/site-packages/celerite2/numpy.py", line 105, in _do_norm
#     alpha = driver.solve_lower(
# KeyboardInterrupt
#  42%|████▏     | 42345/100000 [1:05:16<1:28:53, 10.81it/s]Process ForkPoolWorker-40:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-46:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-29:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/rk19047/anaconda3/envs/MSci_project_solva/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# emcee: Exception while calling your likelihood function:
#   params: [0.53553376 3.34543359]
#   args: (array([0.9914634, 0.9958379, 0.9909146, ..., 0.9937734, 0.9988129,
#        1.0000453], dtype=float32), array([0.00222942, 0.00223049, 0.00222878, ..., 0.00218562, 0.00219034,
#        0.00219494], dtype=float32))
#   kwargs: {}
#   exception:
# KeyboardInterrupt

# %%
samples = sampler.get_chain()
tau = sampler.get_autocorr_time()
print(tau)

# %%
burnin = int(5 * np.max(tau))
thin = int(0.5 * np.min(tau))
flat_samples = sampler.get_chain(discard=burnin, thin=thin, flat=True)
print(flat_samples.shape)

# %%
filename = "matern32_tess_flat_samples.p"
file = open(filename, "wb")
pickle.dump(samples, file)
file.close()

# %%
fig, axes = plt.subplots(len(guess), figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["$\\sigma$", "$\\rho$"]

for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.axvline(x = burnin, color ='red', ls="--", alpha=0.7)
    ax.set_ylabel(labels[i])

axes[-1].set_xlabel("Step number")
plt.show()

# %%
fig = corner.corner(
    flat_samples, labels=labels)
